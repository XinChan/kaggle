# %%
# 导入需要的模块
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 用来绘图的，封装了matplot
# 要注意的是一旦导入了seaborn，
# matplotlib的默认作图风格就会被覆盖成seaborn的格式
import seaborn as sns       

from scipy import stats
from scipy.stats import  norm
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline  
# 为了在jupyter notebook里作图，需要用到这个命令

# %%
data_train = pd.read_csv('train.csv', header = None)
data_test = pd.read_csv('test.csv', header  = None)
data_label = pd.read_csv('trainLabels.csv', header  = None)
combine = [data_train, data_test]

# %%
data_train.head(3)
# Out:
#    0.29940251144353242  -1.2266241875260637  1.4984250500215328  \
# 0            -1.174176             0.332157            0.949919
# 1             1.192222            -0.414371            0.067054
# 2             1.573270            -0.580318           -0.866332
#
#    -1.1761503610375272  5.2898525545597037  0.20829711393323402  \
# 0            -1.285328            2.199061            -0.151268
# 1            -2.233568            3.658881             0.089007
# 2            -0.603812            3.125716             0.870321
#
#    2.4044983672405826  1.5945062220589785  -0.051608163273514231  \
# 0           -0.427039            2.619246              -0.765884
# 1            0.203439           -4.219054              -1.184919
# 2           -0.161992            4.499666               1.038741
#
#    0.66323431039687908  ...  -0.85046544625016463  -0.62298999638261954  \
# 0            -0.093780  ...             -0.819750              0.012037
# ...

# %%
data_test.head(2)
# Out:
#    2.8089094884322816  -0.2428941541280098  -0.54642134078742799  \
# 0           -0.374101             0.537669              0.081063
# 1           -0.088370             0.154743              0.380716
#
#    0.25516185655651813  1.7497359401586778  -0.030457614747139938  \
# 0             0.756773            0.915231               2.557282
# 1            -1.176126            1.699867              -0.258627
#
#    -1.3220705648016891  3.5780706827705329  -0.66757846469285065  \
# 0             3.703187            1.673835             -0.764122
# 1            -1.384999            1.093584              1.596633
#
#    -0.88425685382194696  ...  -0.26168811207868709  -0.22437538915802702  \
# 0             -1.228040  ...             -0.969463              0.574154
# 1              0.230631  ...             -0.769885             -0.005143
#
#    -1.6756055243798111  -0.47958360985977283  -0.24438814509352236  \
# 0            -2.200519             -1.612240              0.179031
# ...

# %%
train_columns = data_train.columns

# %%
test_columns = data_test.columns

# %%
count = 0

# %%
for elem in train_columns:
    if elem in test_columns:
        count += 1

# %%
count
# Out:
# 0

# %%
data_train.describe()
# Out:
#        0.29940251144353242  -1.2266241875260637  1.4984250500215328  \
# count           999.000000           999.000000          999.000000
# mean              0.025322            -0.023323           -0.025612
# std               1.008750             1.016094            0.978412
# min              -3.365711            -3.492086           -2.695602
# 25%              -0.670358            -0.690859           -0.700048
# 50%               0.023121            -0.031181            0.008037
# 75%               0.762980             0.683464            0.657948
# max               3.326246             3.583870            2.546507
#
#        -1.1761503610375272  5.2898525545597037  0.20829711393323402  \
# count           999.000000          999.000000           999.000000
# mean             -0.001096            1.088127            -0.006465
# std               0.970349            4.539161             0.989601
# min              -3.460471          -16.421901            -3.041250
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# 获取数据
x = data_train.values
y = data_label.values
x_scaled = preprocessing.StandardScaler().fit_transform(x)

# %%
clfs = {
        'logreg': LogisticRegression(),
        'svc' : SVC(),
        'knn' :  KNeighborsClassifier(),
        'gaussian' :  GaussianNB(),
        'linear_svc' :  LinearSVC(),
        'sgd' :  SGDClassifier(),
        'dtc' :  DecisionTreeClassifier(),
        'random_forest' :  RandomForestClassifier()
       }
for clf in clfs:
    try:
        clfs[clf].fit(x_scaled, y)
        print( round(clfs[clf].score(x_scaled, y) * 100, 2) )
    except Exception as e:
        print(clf + " Error:")
        print(str(e))
# Out:
# 83.8
# 95.6
# 90.7
# 83.4
# 83.6
# 75.6
# 100.0
# 99.5

# %%
ids = np.arange(1,9001)

# %%
ids
# Out:
# array([   1,    2,    3, ..., 8998, 8999, 9000])

# %%
clf_selection =  RandomForestClassifier()
clf_selection.fit(x_scaled,y)
test_x = data_test.values
test_x_scaled = preprocessing.StandardScaler().fit_transform(test_x)
result = clf_selection.predict(test_x_scaled)

# %%
result.shape
# Out:
# (9000,)

# %%
submission = pd.DataFrame({
    'Id':ids,
    'Solution':result
})

# %%
data_test.shape
# Out:
# (9000, 40)

# %%
submission.to_csv('submission1.csv', index = False)

# %%
data_train.shape
# Out:
# (999, 40)
